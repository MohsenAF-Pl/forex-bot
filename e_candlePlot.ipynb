# %%
import pandas as pd
import toolbox
import c_instrument

# %%
pair = "USD_CAD"
granularity = "H1"
ma_list = [8, 32]
i_pair = c_instrument.Instrument.get_instrument_by_name(pair)

# %%
df = pd.read_pickle(toolbox.get_hist_data_filename(pair, granularity))

# %%
df.head()
# Out:
#                              time  volume    mid_o    mid_h    mid_l    mid_c  \
# 0  2022-01-06T17:00:00.000000000Z    1688  1.27266  1.27292  1.27066  1.27189
# 1  2022-01-06T18:00:00.000000000Z     848  1.27186  1.27315  1.27158  1.27253
# 2  2022-01-06T19:00:00.000000000Z    1165  1.27256  1.27312  1.27198  1.27298
# 3  2022-01-06T20:00:00.000000000Z    1056  1.27296  1.27400  1.27264  1.27272
# 4  2022-01-06T21:00:00.000000000Z     457  1.27274  1.27318  1.27234  1.27244
#
#      bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c
# 0  1.27256  1.27280  1.27055  1.27179  1.27276  1.27304  1.27077  1.27199
# 1  1.27176  1.27306  1.27148  1.27243  1.27197  1.27324  1.27168  1.27263
# 2  1.27245  1.27302  1.27187  1.27288  1.27266  1.27322  1.27208  1.27308
# 3  1.27285  1.27390  1.27254  1.27263  1.27307  1.27410  1.27273  1.27281
# 4  1.27265  1.27309  1.27221  1.27221  1.27284  1.27326  1.27245  1.27266

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    3999 non-null   object
#  1   volume  3999 non-null   int64
#  2   mid_o   3999 non-null   object
#  3   mid_h   3999 non-null   object
#  4   mid_l   3999 non-null   object
#  5   mid_c   3999 non-null   object
#  6   bid_o   3999 non-null   object
#  7   bid_h   3999 non-null   object
#  8   bid_l   3999 non-null   object
#  9   bid_c   3999 non-null   object
#  10  ask_o   3999 non-null   object
#  11  ask_h   3999 non-null   object
#  12  ask_l   3999 non-null   object
#  13  ask_c   3999 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 437.5+ KB

# %%
non_cols = ['time', 'volume']

# %%
mod_cols = [x for x in df.columns if x not in non_cols]

# %%
df[mod_cols] = df[mod_cols].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    3999 non-null   object
#  1   volume  3999 non-null   int64
#  2   mid_o   3999 non-null   float64
#  3   mid_h   3999 non-null   float64
#  4   mid_l   3999 non-null   float64
#  5   mid_c   3999 non-null   float64
#  6   bid_o   3999 non-null   float64
#  7   bid_h   3999 non-null   float64
#  8   bid_l   3999 non-null   float64
#  9   bid_c   3999 non-null   float64
#  10  ask_o   3999 non-null   float64
#  11  ask_h   3999 non-null   float64
#  12  ask_l   3999 non-null   float64
#  13  ask_c   3999 non-null   float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 437.5+ KB

# %%
df_ma = df[['time', 'mid_o', 'mid_h', 'mid_l', 'mid_c']].copy()

# %%
df_ma.head()
# Out:
#                              time    mid_o    mid_h    mid_l    mid_c
# 0  2022-01-06T17:00:00.000000000Z  1.27266  1.27292  1.27066  1.27189
# 1  2022-01-06T18:00:00.000000000Z  1.27186  1.27315  1.27158  1.27253
# 2  2022-01-06T19:00:00.000000000Z  1.27256  1.27312  1.27198  1.27298
# 3  2022-01-06T20:00:00.000000000Z  1.27296  1.27400  1.27264  1.27272
# 4  2022-01-06T21:00:00.000000000Z  1.27274  1.27318  1.27234  1.27244

# %%
for ma in ma_list:
    df_ma[f'ma_{ma}'] = df_ma.mid_c.rolling(window=ma).mean()

# %%
df_ma.dropna(inplace=True)

# %%
df_ma.reset_index(drop=True, inplace=True)

# %%
df_ma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3968 entries, 0 to 3967
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    3968 non-null   object
#  1   mid_o   3968 non-null   float64
#  2   mid_h   3968 non-null   float64
#  3   mid_l   3968 non-null   float64
#  4   mid_c   3968 non-null   float64
#  5   ma_8    3968 non-null   float64
#  6   ma_32   3968 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 217.1+ KB

# %%
df_ma.head()
# Out:
#                              time    mid_o    mid_h    mid_l    mid_c  \
# 0  2022-01-10T00:00:00.000000000Z  1.26476  1.26508  1.26376  1.26402
# 1  2022-01-10T01:00:00.000000000Z  1.26398  1.26492  1.26376  1.26384
# 2  2022-01-10T02:00:00.000000000Z  1.26381  1.26459  1.26346  1.26442
# 3  2022-01-10T03:00:00.000000000Z  1.26446  1.26494  1.26428  1.26443
# 4  2022-01-10T04:00:00.000000000Z  1.26445  1.26452  1.26384  1.26433
#
#        ma_8     ma_32
# 0  1.264312  1.269550
# 1  1.264200  1.269298
# 2  1.264255  1.269045
# 3  1.264376  1.268778
# 4  1.264398  1.268516

# %%
df_ma['diff'] = df_ma.ma_8 - df_ma.ma_32

# %%
df_ma['diff_prev'] = df_ma['diff'].shift(1)

# %%
df_ma.dropna(inplace=True)

# %%
df_ma.reset_index(drop=True, inplace=True)

# %%
# we'll use this function to identify the trades based on ma

def is_trade(row):
    if row['diff'] >= 0 and row['diff_prev'] < 0:
        return 1
    if row['diff'] <= 0 and row['diff_prev'] > 0:
        return -1
    return 0

# %%
df_ma['is_trade'] = df_ma.apply(is_trade, axis=1)

# %%
df_trades = df_ma[df_ma.is_trade!=0].copy()

# %%
df_trades.head()
# Out:
#                                time    mid_o    mid_h    mid_l    mid_c  \
# 16   2022-01-10T17:00:00.000000000Z  1.26788  1.26966  1.26734  1.26942
# 30   2022-01-11T07:00:00.000000000Z  1.26612  1.26618  1.26434  1.26461
# 93   2022-01-13T22:00:00.000000000Z  1.25162  1.25188  1.25048  1.25142
# 104  2022-01-14T09:00:00.000000000Z  1.24733  1.24854  1.24710  1.24819
# 108  2022-01-14T13:00:00.000000000Z  1.25158  1.25352  1.25055  1.25271
#
#          ma_8     ma_32      diff  diff_prev  is_trade
# 16   1.266354  1.265887  0.000467  -0.000472         1
# 30   1.265541  1.265612 -0.000070   0.000176        -1
# 93   1.249857  1.249546  0.000312  -0.000382         1
# 104  1.249332  1.249371 -0.000039   0.000343        -1
# 108  1.249513  1.249438  0.000074  -0.000327         1

# %%
df_trades['delta'] = (df_trades.mid_c.diff() / i_pair.pipLocation).shift(-1)
df_trades['gain'] = df_trades['delta'] * df_trades['is_trade']

# %%
from dateutil.parser import *
df_trades['time'] = [parse(x) for x in df_trades.time]

# %%
df_trades['duration'] = df_trades.time.diff().shift(-1)

# %%
df_trades['duration'] = [x.total_seconds() / 3600 for x in df_trades.duration]

# %%
df_all = pd.read_pickle('./data/all_trades.pkl')

# %%
df_all.head()
# Out:
#                          time    mid_c          diff  diff_prev  is_trade  \
# 46  2022-01-10 14:00:00+00:00  1.35392 -6.250000e-07   0.000544        -1
# 58  2022-01-11 02:00:00+00:00  1.35877  1.562500e-05  -0.000216         1
# 127 2022-01-13 23:00:00+00:00  1.37130 -3.484375e-04   0.000004        -1
# 134 2022-01-14 06:00:00+00:00  1.37294  1.331250e-04  -0.000025         1
# 141 2022-01-14 13:00:00+00:00  1.37004 -5.531250e-05   0.000322        -1
#
#      delta   gain     pair  mashort  malong  duration
# 46    48.5  -48.5  GBP_USD        8      32      12.0
# 58   125.3  125.3  GBP_USD        8      32      69.0
# 127   16.4  -16.4  GBP_USD        8      32       7.0
# 134  -29.0  -29.0  GBP_USD        8      32       7.0
# 141  -70.2   70.2  GBP_USD        8      32     118.0

# %%
df_all.describe()
# Out:
#               mid_c          diff     diff_prev      is_trade         delta  \
# count  21528.000000  21528.000000  2.152800e+04  21528.000000  21528.000000
# mean      32.930059     -0.000226  1.210989e-04     -0.000372     -2.043167
# std       54.740660      0.018169  1.791413e-02      1.000023    117.444880
# min        0.590820     -0.291102 -2.266458e-01     -1.000000  -1394.200000
# 25%        0.915040     -0.000179 -1.817318e-04     -1.000000    -42.800000
# 50%        1.291220      0.000000  7.812500e-08     -1.000000     -2.100000
# 75%       81.655250      0.000180  1.813021e-04      1.000000     37.800000
# max      167.945000      0.249208  3.460625e-01      1.000000   1464.200000
#
#                gain       mashort        malong      duration
# count  21528.000000  21528.000000  21528.000000  21528.000000
# mean       2.823871     19.642884     94.057228     86.850753
# std      117.428701     16.236200     65.430258    114.491209
# min     -539.200000      8.000000     32.000000      1.000000
# 25%      -47.900000      8.000000     32.000000     17.000000
# 50%      -18.600000     16.000000     64.000000     48.000000
# 75%       18.300000     32.000000    128.000000    116.000000
# max     1464.200000     64.000000    256.000000   1757.000000

# %%
df_all['gain'].max()
# Out:
# 1464.1999999999982

# %%
df_trades[['time', 'duration']].head()
# Out:
#                          time  duration
# 16  2022-01-10 17:00:00+00:00      14.0
# 30  2022-01-11 07:00:00+00:00      63.0
# 93  2022-01-13 22:00:00+00:00      11.0
# 104 2022-01-14 09:00:00+00:00       4.0
# 108 2022-01-14 13:00:00+00:00      70.0

# %%
df_trades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 16 to 3937
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       151 non-null    datetime64[ns, tzutc()]
#  1   mid_o      151 non-null    float64
#  2   mid_h      151 non-null    float64
#  3   mid_l      151 non-null    float64
#  4   mid_c      151 non-null    float64
#  5   ma_8       151 non-null    float64
#  6   ma_32      151 non-null    float64
#  7   diff       151 non-null    float64
#  8   diff_prev  151 non-null    float64
#  9   is_trade   151 non-null    int64
#  10  delta      150 non-null    float64
#  11  gain       150 non-null    float64
# dtypes: datetime64[ns, tzutc()](1), float64(10), int64(1)
# memory usage: 15.3 KB

# %%
df_trades['gain'].sum()
# Out:
# -96.39999999999208

# %%
df_ma.head()
# Out:
#                              time    mid_o    mid_h    mid_l    mid_c  \
# 0  2022-01-10T00:00:00.000000000Z  1.13538  1.13582  1.13516  1.13552
# 1  2022-01-10T01:00:00.000000000Z  1.13551  1.13566  1.13499  1.13502
# 2  2022-01-10T02:00:00.000000000Z  1.13504  1.13520  1.13393  1.13396
# 3  2022-01-10T03:00:00.000000000Z  1.13398  1.13398  1.13339  1.13376
# 4  2022-01-10T04:00:00.000000000Z  1.13374  1.13406  1.13334  1.13343
#
#        ma_8     ma_32      diff  diff_prev  is_trade
# 0  1.135831  1.131850  0.003982   0.004147     False
# 1  1.135750  1.132020  0.003730   0.003982     False
# 2  1.135525  1.132169  0.003356   0.003730     False
# 3  1.135210  1.132328  0.002882   0.003356     False
# 4  1.134874  1.132462  0.002412   0.002882     False

# %%
import plotly.graph_objects as go

# %%
df_plot = df_ma.iloc[-200:].copy()

# %%
df_plot.shape
# Out:
# (200, 11)

# %%
from matplotlib.widgets import RangeSlider


fig = go.Figure()
fig.add_trace(go.Candlestick(
    x=df_plot.time, open=df_plot.mid_o, high=df_plot.mid_h, low=df_plot.mid_h, close=df_plot.mid_c,
    line=dict(width=1), opacity=1
))
for ma in ma_list:
    col = f"ma_{ma}"
    fig.add_trace(go.Scatter(x=df_plot.time, y=df_plot[col], line=dict(width=2), line_shape='spline', name=col))
fig.update_layout(width=1000, height=400,
margin=dict(l=10, r=10, b=10, t=10),
paper_bgcolor="#1e1e1e", plot_bgcolor="#1e1e1e")
fig.update_xaxes(
    gridcolor="#1f292f",
    showgrid=True, fixedrange=True,rangeslider=dict(visible=False)
)
fig.show()
